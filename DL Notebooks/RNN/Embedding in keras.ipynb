# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding

docs = ['go india',
        'india india',
        'hip hip hurray',
        'jeetega bhai jeetega india jeetega',
        'bharat mata ki jai',
        'kohli kohli',
        'sachin sachin',
        'dhoni dhoni',
        'modi ji ki jai',
        'inquilab zindabad']

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(docs)

sequences = tokenizer.texts_to_sequences(docs)

# Padding
sequences = pad_sequences(sequences, maxlen=5, padding='post')

print("Sequences shape:", sequences.shape)

# Model
model = Sequential()
model.add(Embedding(input_dim=17, output_dim=2, input_shape=(5,)))

model.compile(optimizer='adam', loss='mse')

model.summary()

# Prediction
pred = model.predict(sequences)

print(pred)
# Out:
# Sequences shape: (10, 5)
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_16 (Embedding)             │ (None, 5, 2)                │              34 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 34 (136.00 B)
#  Trainable params: 34 (136.00 B)
#  Non-trainable params: 0 (0.00 B)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[72], line 38
#      35 model.summary()
#      37 # Prediction
# ---> 38 pred = model.predict(sequences)
#      40 print(pred)
#
# File ~\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\envs\dl\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_17_1/embedding_16_1/GatherV2 defined at (most recent call last):
#   File "C:\Users\himan\anaconda3\envs\dl\lib\runpy.py", line 196, in _run_module_as_main
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\runpy.py", line 86, in _run_code
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\asyncio\base_events.py", line 603, in run_forever
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\asyncio\base_events.py", line 1909, in _run_once
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\asyncio\events.py", line 80, in _run
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 519, in dispatch_queue
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 508, in process_one
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 400, in dispatch_shell
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\ipkernel.py", line 368, in execute_request
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\ipkernel.py", line 455, in do_execute
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\zmqshell.py", line 602, in run_cell
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#
#   File "C:\Users\himan\AppData\Local\Temp\ipykernel_28812\1866057250.py", line 38, in <module>
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 588, in predict
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 282, in one_step_on_data_distributed
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 125, in wrapper
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 271, in one_step_on_data
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 110, in predict_step
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\layers\layer.py", line 941, in __call__
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\models\sequential.py", line 220, in call
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\models\functional.py", line 183, in call
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\ops\function.py", line 206, in _run_through_graph
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\models\functional.py", line 644, in call
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\layers\layer.py", line 941, in __call__
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\layers\core\embedding.py", line 158, in call
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\ops\numpy.py", line 6193, in take
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\numpy.py", line 2589, in take
#
# indices[9,1] = 17 is not in [0, 17)
# 	 [[{{node sequential_17_1/embedding_16_1/GatherV2}}]] [Op:__inference_one_step_on_data_distributed_5060]

# %%
print("Model input:", model.input_shape)
print("Data shape:", sequences.shape)
# Out:
# Model input: (None, 5)
# Data shape: (10, 5)

# %%
model = Sequential()

model.add(Embedding(input_dim=17, output_dim=2, input_shape=(5,)))

model.summary()
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_14 (Embedding)             │ (None, 5, 2)                │              34 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 34 (136.00 B)
#  Trainable params: 34 (136.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='mse')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 pred = model.predict(sequences)
#       2 print(pred)
#
# File ~\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\envs\dl\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_15_1/embedding_14_1/GatherV2 defined at (most recent call last):
#   File "C:\Users\himan\anaconda3\envs\dl\lib\runpy.py", line 196, in _run_module_as_main
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\runpy.py", line 86, in _run_code
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\asyncio\base_events.py", line 603, in run_forever
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\asyncio\base_events.py", line 1909, in _run_once
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\asyncio\events.py", line 80, in _run
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 519, in dispatch_queue
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 508, in process_one
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 400, in dispatch_shell
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\ipkernel.py", line 368, in execute_request
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\ipkernel.py", line 455, in do_execute
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\ipykernel\zmqshell.py", line 602, in run_cell
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#
#   File "C:\Users\himan\AppData\Local\Temp\ipykernel_28812\2269839758.py", line 1, in <module>
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 588, in predict
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 282, in one_step_on_data_distributed
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 125, in wrapper
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 271, in one_step_on_data
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 110, in predict_step
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\layers\layer.py", line 941, in __call__
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\models\sequential.py", line 220, in call
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\models\functional.py", line 183, in call
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\ops\function.py", line 206, in _run_through_graph
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\models\functional.py", line 644, in call
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\layers\layer.py", line 941, in __call__
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\layers\core\embedding.py", line 158, in call
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\ops\numpy.py", line 6193, in take
#
#   File "C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\backend\tensorflow\numpy.py", line 2589, in take
#
# indices[9,1] = 17 is not in [0, 17)
# 	 [[{{node sequential_15_1/embedding_14_1/GatherV2}}]] [Op:__inference_one_step_on_data_distributed_4799]
