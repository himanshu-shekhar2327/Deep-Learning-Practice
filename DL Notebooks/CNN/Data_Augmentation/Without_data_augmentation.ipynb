# %%
# conda install -c conda-forge opencv
# Out:
# Jupyter detected...
# Note: you may need to restart the kernel to use updated packages.
#
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\himan\anaconda3\envs\dl
#
#   added / updated specs:
#     - opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libavif_api-1.3.0         |       h57928b3_3          10 KB  conda-forge
#     aom-3.9.1                  |       he0c23c2_0         1.9 MB  conda-forge
#     ca-certificates-2026.1.4   |       h4c7d964_0         144 KB  conda-forge
#     eigen-3.4.0                |       h477610d_1         1.1 MB  conda-forge
#     ffmpeg-6.1.1               |       haa678a1_5        10.4 MB
#     freeglut-3.8.0             |       hfcef157_0         117 KB
#     gflags-2.2.2               |    he0c23c2_1005          75 KB  conda-forge
#     glog-0.5.0                 |       h4797de2_0          90 KB  conda-forge
#     gst-plugins-base-1.24.12   |       h91a6125_1         2.0 MB
#     gstreamer-1.24.12          |       hfb93a4f_1         1.7 MB
#     gstreamer-orc-0.4.42       |       h6c41571_0         203 KB  conda-forge
#     hdf5-1.14.5                |       ha36df97_2         2.1 MB
#     lcms2-2.17                 |       h3732fa5_0         514 KB
#     libabseil-20250814.1       | cxx17_habfad5f_0         1.7 MB  conda-forge
#     libavif-1.3.0              |       ha08a409_3          47 KB  conda-forge
#     libavif16-1.3.0            |       ha08a409_3         115 KB  conda-forge
#     libdeflate-1.22            |       h2466b09_0         152 KB  conda-forge
#     libopenjpeg-2.5.4          |       h02ab6af_1         183 KB
#     libprotobuf-6.33.0         |       h68bd463_0         7.1 MB  conda-forge
#     libtheora-1.2.0            |       habf309d_1         151 KB
#     opencv-4.12.0              |  py310h42193b7_1        36.2 MB
#     openjpeg-2.5.4             |       h24db6dd_0         239 KB  conda-forge
#     openssl-3.6.1              |       hf411b9b_1         8.9 MB  conda-forge
#     pillow-12.0.0              |  py310h4212202_1         742 KB
#     rav1e-0.7.1                |       ha073cba_3         3.9 MB  conda-forge
#     svt-av1-4.0.0              |       hac47afa_0         1.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        81.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libavif_api       conda-forge/win-64::_libavif_api-1.3.0-h57928b3_3
#   aom                conda-forge/win-64::aom-3.9.1-he0c23c2_0
#   dav1d              conda-forge/win-64::dav1d-1.2.1-hcfcfb64_0
#   eigen              conda-forge/win-64::eigen-3.4.0-h477610d_1
#   ffmpeg             pkgs/main/win-64::ffmpeg-6.1.1-haa678a1_5
#   freeglut           pkgs/main/win-64::freeglut-3.8.0-hfcef157_0
#   fribidi            conda-forge/win-64::fribidi-1.0.16-hfd05255_0
#   gflags             conda-forge/win-64::gflags-2.2.2-he0c23c2_1005
#   glog               conda-forge/win-64::glog-0.5.0-h4797de2_0
#   gst-plugins-base   pkgs/main/win-64::gst-plugins-base-1.24.12-h91a6125_1
#   gstreamer          pkgs/main/win-64::gstreamer-1.24.12-hfb93a4f_1
#   gstreamer-orc      conda-forge/win-64::gstreamer-orc-0.4.42-h6c41571_0
#   hdf5               pkgs/main/win-64::hdf5-1.14.5-ha36df97_2
#   libabseil          conda-forge/win-64::libabseil-20250814.1-cxx17_habfad5f_0
#   libavif            conda-forge/win-64::libavif-1.3.0-ha08a409_3
#   libavif16          conda-forge/win-64::libavif16-1.3.0-ha08a409_3
#   libogg             conda-forge/win-64::libogg-1.3.5-h2466b09_1
#   libopenjpeg        pkgs/main/win-64::libopenjpeg-2.5.4-h02ab6af_1
#   libprotobuf        conda-forge/win-64::libprotobuf-6.33.0-h68bd463_0
#   libtheora          pkgs/main/win-64::libtheora-1.2.0-habf309d_1
#   libvorbis          conda-forge/win-64::libvorbis-1.3.7-h5112557_2
#   opencv             pkgs/main/win-64::opencv-4.12.0-py310h42193b7_1
#   rav1e              conda-forge/win-64::rav1e-0.7.1-ha073cba_3
#   svt-av1            conda-forge/win-64::svt-av1-4.0.0-hac47afa_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main/win-64::ca-certificates-202~ --> conda-forge/noarch::ca-certificates-2026.1.4-h4c7d964_0
#   lcms2                                     2.16-hb4a4139_0 --> 2.17-h3732fa5_0
#   lerc                       pkgs/main::lerc-3.0-hd77b12b_0 --> conda-forge::lerc-4.0.0-h6470a55_1
#   libdeflate          pkgs/main::libdeflate-1.17-h2bbff1b_1 --> conda-forge::libdeflate-1.22-h2466b09_0
#   libtiff                                  4.5.1-hd77b12b_0 --> 4.7.1-h3a18249_0
#   openjpeg             pkgs/main::openjpeg-2.5.2-hae555c5_0 --> conda-forge::openjpeg-2.5.4-h24db6dd_0
#   openssl              pkgs/main::openssl-3.0.18-h543e019_0 --> conda-forge::openssl-3.6.1-hf411b9b_1
#   pillow                             11.1.0-py310h096bfcc_0 --> 12.0.0-py310h4212202_1
#
#
#
# Downloading and Extracting Packages: ...working...
# opencv-4.12.0        | 36.2 MB   |            |   0%
#
# ffmpeg-6.1.1         | 10.4 MB   |            |   0%
#
#
# openssl-3.6.1        | 8.9 MB    |            |   0%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    |            |   0%
#
#
#
#
# rav1e-0.7.1          | 3.9 MB    |            |   0%
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    |            |   0%
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    |            |   0%
#
#
#
#
#
#
#
# aom-3.9.1            | 1.9 MB    |            |   0%
#
#
#
#
#
#
#
#
# gstreamer-1.24.12    | 1.7 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# libabseil-20250814.1 | 1.7 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# svt-av1-4.0.0        | 1.7 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# eigen-3.4.0          | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-12.0.0        | 742 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.17           | 514 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.4       | 239 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gstreamer-orc-0.4.42 | 203 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenjpeg-2.5.4    | 183 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 152 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtheora-1.2.0      | 151 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# opencv-4.12.0        | 36.2 MB   |            |   0%
#
#
# openssl-3.6.1        | 8.9 MB    |            |   0%
#
#
#
#
# rav1e-0.7.1          | 3.9 MB    |            |   0%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    |            |   0%
#
# ffmpeg-6.1.1         | 10.4 MB   |            |   0%
# opencv-4.12.0        | 36.2 MB   |            |   1%
#
#
# openssl-3.6.1        | 8.9 MB    | 2          |   2%
#
#
#
#
# rav1e-0.7.1          | 3.9 MB    | 4          |   4%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    | 2          |   3%
#
# ffmpeg-6.1.1         | 10.4 MB   | 1          |   2%
# opencv-4.12.0        | 36.2 MB   | 1          |   2%
#
#
# openssl-3.6.1        | 8.9 MB    | 6          |   6%
#
#
#
#
# rav1e-0.7.1          | 3.9 MB    | #3         |  13%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    | 7          |   7%
#
# ffmpeg-6.1.1         | 10.4 MB   | 4          |   5%
# opencv-4.12.0        | 36.2 MB   | 5          |   5%
#
#
# openssl-3.6.1        | 8.9 MB    | #8         |  18%
#
#
#
#
# rav1e-0.7.1          | 3.9 MB    | ####2      |  42%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    | #9         |  19%
#
# ffmpeg-6.1.1         | 10.4 MB   | #2         |  13%
# opencv-4.12.0        | 36.2 MB   | 9          |   9%
#
#
# openssl-3.6.1        | 8.9 MB    | ###2       |  33%
#
#
#
#
# rav1e-0.7.1          | 3.9 MB    | #######    |  71%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    | ###4       |  34%
#
# ffmpeg-6.1.1         | 10.4 MB   | #8         |  19%
# opencv-4.12.0        | 36.2 MB   | #2         |  12%
#
#
#
#
# rav1e-0.7.1          | 3.9 MB    | #########  |  90%
#
#
# openssl-3.6.1        | 8.9 MB    | ####2      |  42%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    | ####4      |  44%
#
#
#
#
# rav1e-0.7.1          | 3.9 MB    | ########## | 100%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    | ######2    |  62%
#
#
#
#
# rav1e-0.7.1          | 3.9 MB    | ########## | 100%
#
# ffmpeg-6.1.1         | 10.4 MB   | ##3        |  24%
#
#
# openssl-3.6.1        | 8.9 MB    | ####9      |  50%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    | #######3   |  74%
# opencv-4.12.0        | 36.2 MB   | #4         |  14%
#
#
# openssl-3.6.1        | 8.9 MB    | #####6     |  56%
#
# ffmpeg-6.1.1         | 10.4 MB   | ##7        |  28%
# opencv-4.12.0        | 36.2 MB   | ##2        |  22%
#
#
# openssl-3.6.1        | 8.9 MB    | ########5  |  86%
#
# ffmpeg-6.1.1         | 10.4 MB   | ###4       |  34%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    | ########5  |  85%
# opencv-4.12.0        | 36.2 MB   | ##8        |  28%
#
#
# openssl-3.6.1        | 8.9 MB    | ########## | 100%
#
#
# openssl-3.6.1        | 8.9 MB    | ########## | 100%
#
# ffmpeg-6.1.1         | 10.4 MB   | ####1      |  41%
# opencv-4.12.0        | 36.2 MB   | ###5       |  35%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    | ########## | 100%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    | ########## | 100%
#
# ffmpeg-6.1.1         | 10.4 MB   | ####8      |  49%
# opencv-4.12.0        | 36.2 MB   | ####2      |  42%
#
# ffmpeg-6.1.1         | 10.4 MB   | #####6     |  56%
#
#
#
#
#
#
#
# aom-3.9.1            | 1.9 MB    |            |   1%
# opencv-4.12.0        | 36.2 MB   | ####8      |  49%
#
# ffmpeg-6.1.1         | 10.4 MB   | ######3    |  64%
#
#
#
#
#
#
#
# aom-3.9.1            | 1.9 MB    | #######5   |  75%
# opencv-4.12.0        | 36.2 MB   | #####6     |  57%
#
#
#
#
#
#
#
# aom-3.9.1            | 1.9 MB    | ########## | 100%
#
# ffmpeg-6.1.1         | 10.4 MB   | #######1   |  72%
# opencv-4.12.0        | 36.2 MB   | ######4    |  64%
#
# ffmpeg-6.1.1         | 10.4 MB   | #######9   |  80%
# opencv-4.12.0        | 36.2 MB   | #######3   |  73%
#
#
#
#
#
#
#
# aom-3.9.1            | 1.9 MB    | ########## | 100%
#
# ffmpeg-6.1.1         | 10.4 MB   | ########7  |  88%
# opencv-4.12.0        | 36.2 MB   | ########1  |  82%
#
# ffmpeg-6.1.1         | 10.4 MB   | #########6 |  97%
# opencv-4.12.0        | 36.2 MB   | #########1 |  91%
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    |            |   1%
#
# ffmpeg-6.1.1         | 10.4 MB   | ########## | 100%
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | #          |  10%
#
#
# openssl-3.6.1        | 8.9 MB    | ########## | 100%
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | ###1       |  31%
# opencv-4.12.0        | 36.2 MB   | ########## | 100%
# opencv-4.12.0        | 36.2 MB   | ########## | 100%
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | #########9 | 100%
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# gstreamer-1.24.12    | 1.7 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
#
# eigen-3.4.0          | 1.1 MB    | 1          |   1%
#
#
#
#
#
#
#
#
# gstreamer-1.24.12    | 1.7 MB    | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
# eigen-3.4.0          | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# gstreamer-1.24.12    | 1.7 MB    | ###1       |  31%
#
#
#
#
#
#
#
#
# gstreamer-1.24.12    | 1.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# gstreamer-1.24.12    | 1.7 MB    | ########## | 100%
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.17           | 514 KB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.17           | 514 KB    | ########## | 100%
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.4       | 239 KB    | 6          |   7%
#
#
#
#
#
#
#
#
#
# libabseil-20250814.1 | 1.7 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.4       | 239 KB    | ########## | 100%
#
# ffmpeg-6.1.1         | 10.4 MB   | ########## | 100%
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-12.0.0        | 742 KB    | 2          |   2%
#
#
#
#
#
#
#
#
#
# libabseil-20250814.1 | 1.7 MB    | 8          |   9%
#
#
#
# libprotobuf-6.33.0   | 7.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# svt-av1-4.0.0        | 1.7 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gstreamer-orc-0.4.42 | 203 KB    | 7          |   8%
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ######4    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gstreamer-orc-0.4.42 | 203 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-12.0.0        | 742 KB    | ######8    |  69%
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libabseil-20250814.1 | 1.7 MB    | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
# svt-av1-4.0.0        | 1.7 MB    | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenjpeg-2.5.4    | 183 KB    | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-12.0.0        | 742 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenjpeg-2.5.4    | 183 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 152 KB    | #          |  11%
#
#
#
#
#
#
#
#
#
# libabseil-20250814.1 | 1.7 MB    | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 152 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# svt-av1-4.0.0        | 1.7 MB    | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtheora-1.2.0      | 151 KB    | #          |  11%
#
#
#
#
#
#
#
#
#
# libabseil-20250814.1 | 1.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtheora-1.2.0      | 151 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# svt-av1-4.0.0        | 1.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# svt-av1-4.0.0        | 1.7 MB    | ########## | 100%
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# gstreamer-1.24.12    | 1.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.17           | 514 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.17           | 514 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.4       | 239 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.4       | 239 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# eigen-3.4.0          | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# eigen-3.4.0          | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gstreamer-orc-0.4.42 | 203 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gstreamer-orc-0.4.42 | 203 KB    | ########## | 100%
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ########## | 100%
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenjpeg-2.5.4    | 183 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenjpeg-2.5.4    | 183 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 152 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 152 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-12.0.0        | 742 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtheora-1.2.0      | 151 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtheora-1.2.0      | 151 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# svt-av1-4.0.0        | 1.7 MB    | ########## | 100%
# opencv-4.12.0        | 36.2 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
# libabseil-20250814.1 | 1.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import cv2
import os
import random
import numpy as np

# %%
mydir = 'D:/JUPYTER NOTEBOOK/DEEP LEARNING/DL Notebooks/CNN/Data_Augmentation/train_data'

# %%
categories = ['cats', 'dogs']

# %%
data = []
for i in categories:
    folder_path = os.path.join(mydir,i)
    if i == 'cats':
        label = 0
    else:
        label =1 

    for j in os.listdir(folder_path):
        img_path = os.path.join(folder_path , j)
        img = cv2.imread(img_path)
        img = cv2.resize(img, (150,150))
        data.append([img,label])

# %%
data
# Out:
# [[array([[[103, 122, 157],
#           [105, 124, 159],
#           [103, 122, 157],
#           ...,
#           [113, 132, 170],
#           [123, 142, 180],
#           [115, 134, 172]],
#
#          [[109, 128, 163],
#           [110, 129, 164],
#           [108, 127, 162],
#           ...,
#           [114, 133, 171],
#           [118, 137, 175],
#           [117, 136, 173]],
#
#          [[112, 131, 166],
#           [111, 129, 165],
#           [107, 126, 161],
#           ...,
#           [118, 136, 174],
#           [120, 138, 176],
#           [119, 138, 176]],
#
#          ...,
#
#          [[ 33,  49,  74],
#           [ 34,  50,  75],
#           [ 36,  52,  77],
#           ...,
#           [ 33,  47,  62],
#           [ 36,  52,  71],
#           [ 48,  64,  88]],
#
#          [[ 47,  66,  93],
#           [ 46,  65,  92],
#           [ 48,  68,  94],
#           ...,
#           [ 17,  30,  43],
#           [ 31,  45,  62],
#           [ 39,  53,  75]],
#
#          [[ 52,  71,  98],
#           [ 50,  69,  96],
#           [ 51,  70,  97],
#           ...,
#           [  2,   9,  23],
#           [ 16,  24,  41],
#           [ 31,  40,  60]]], dtype=uint8),
#   0],
#  [array([[[176, 169, 171],
#           [165, 158, 161],
#           [164, 156, 159],
#           ...,
#           [168, 169, 171],
#           [192, 186, 187],
#           [185, 177, 178]],
#
#          [[170, 163, 166],
#           [169, 162, 165],
#           [166, 158, 159],
#           ...,
#           [167, 166, 168],
#           [187, 181, 184],
#           [183, 176, 180]],
#
#          [[176, 167, 170],
#           [185, 177, 178],
#           [173, 165, 166],
#           ...,
#           [183, 180, 182],
#           [174, 170, 176],
#           [174, 171, 176]],
#
#          ...,
#
#          [[183, 167, 138],
#           [187, 170, 143],
#           [173, 155, 132],
#           ...,
#           [194, 189, 191],
#           [188, 181, 179],
#           [186, 179, 176]],
#
#          [[172, 153, 126],
#           [171, 151, 126],
#           [174, 153, 132],
#           ...,
#           [192, 187, 189],
#           [187, 179, 179],
#           [187, 180, 179]],
#
#          [[181, 164, 142],
#           [187, 168, 148],
#           [185, 164, 147],
#           ...,
#           [181, 176, 178],
#           [181, 175, 176],
#           [187, 181, 183]]], dtype=uint8),
#   0],
#  [array([[[  3,   6,  11],
#           [  3,   6,  11],
#           [  4,   7,  12],
#           ...,
#           [130, 140, 150],
#           [127, 137, 147],
#           [125, 135, 145]],
#
#          [[  3,   6,  11],
#           [  3,   6,  11],
#           [  4,   7,  12],
#           ...,
#           [139, 149, 159],
#           [130, 140, 150],
#           [140, 150, 160]],
#
#          [[  3,   6,  11],
#           [  3,   6,  11],
#           [  4,   7,  12],
#           ...,
#           [143, 153, 163],
#           [145, 155, 165],
#           [146, 156, 166]],
#
#          ...,
#
#          [[170, 181, 195],
#           [194, 208, 220],
#           [203, 220, 229],
#           ...,
#           [ 75,  62,  46],
#           [ 75,  62,  53],
#           [ 72,  57,  41]],
#
#          [[174, 185, 199],
#           [175, 189, 201],
#           [198, 215, 224],
#           ...,
#           [ 66,  53,  37],
#           [ 71,  58,  49],
#           [ 82,  66,  53]],
#
#          [[192, 203, 217],
#           [173, 187, 199],
#           [202, 219, 228],
#           ...,
#           [ 68,  55,  40],
#           [ 62,  49,  40],
#           [ 65,  47,  41]]], dtype=uint8),
#   0],
#  [array([[[ 32,  55,  87],
#           [ 32,  55,  87],
#           [ 34,  57,  89],
#           ...,
#           [ 15,  63, 111],
#           [ 24,  66, 102],
#           [ 45,  69,  98]],
#
#          [[ 36,  59,  91],
#           [ 36,  59,  91],
#           [ 37,  59,  91],
#           ...,
#           [ 42,  58, 107],
#           [ 50,  58,  95],
#           [ 29,  65, 109]],
#
#          [[ 37,  60,  92],
#           [ 37,  60,  92],
#           [ 36,  59,  91],
#           ...,
#           [ 25,  70, 107],
#           [ 40,  76, 100],
#           [ 48,  70,  97]],
#
#          ...,
#
#          [[ 95, 181, 204],
#           [190, 164, 182],
#           [174, 196, 211],
#           ...,
#           [175, 171, 170],
#           [186, 181, 181],
#           [137, 128, 141]],
#
#          [[ 97, 110, 132],
#           [176, 147, 157],
#           [186, 174, 189],
#           ...,
#           [167, 158, 170],
#           [193, 185, 198],
#           [165, 155, 168]],
#
#          [[131, 105, 127],
#           [168, 142, 148],
#           [141, 124, 138],
#           ...,
#           [169, 159, 174],
#           [178, 176, 189],
#           [168, 155, 169]]], dtype=uint8),
#   0],
#  [array([[[119, 129, 129],
#           [119, 129, 129],
#           [126, 136, 136],
#           ...,
#           [154, 166, 160],
#           [145, 158, 150],
#           [146, 156, 156]],
#
#          [[119, 129, 129],
#           [121, 131, 131],
#           [127, 137, 137],
#           ...,
#           [147, 159, 153],
#           [145, 158, 150],
#           [143, 154, 152]],
#
#          [[120, 130, 130],
#           [124, 134, 134],
#           [125, 135, 135],
#           ...,
#           [146, 158, 152],
#           [146, 159, 151],
#           [148, 159, 156]],
#
#          ...,
#
#          [[117, 126, 135],
#           [121, 130, 139],
#           [122, 132, 139],
#           ...,
#           [144, 149, 148],
#           [136, 141, 140],
#           [134, 139, 138]],
#
#          [[113, 122, 132],
#           [109, 118, 127],
#           [125, 135, 142],
#           ...,
#           [137, 142, 141],
#           [140, 145, 144],
#           [131, 136, 135]],
#
#          [[115, 124, 133],
#           [113, 122, 131],
#           [112, 122, 129],
#           ...,
#           [133, 138, 137],
#           [145, 150, 149],
#           [131, 136, 135]]], dtype=uint8),
#   0],
#  [array([[[195, 224, 238],
#           [179, 206, 219],
#           [167, 194, 214],
#           ...,
#           [110, 147, 197],
#           [114, 150, 198],
#           [104, 144, 197]],
#
#          [[212, 243, 252],
#           [177, 205, 215],
#           [165, 192, 211],
#           ...,
#           [107, 145, 195],
#           [109, 147, 195],
#           [107, 148, 197]],
#
#          [[195, 227, 231],
#           [180, 209, 217],
#           [143, 170, 190],
#           ...,
#           [102, 142, 191],
#           [104, 144, 192],
#           [100, 143, 187]],
#
#          ...,
#
#          [[255, 255, 252],
#           [254, 254, 252],
#           [255, 254, 253],
#           ...,
#           [221, 221, 221],
#           [213, 213, 213],
#           [221, 221, 221]],
#
#          [[252, 252, 252],
#           [253, 253, 253],
#           [254, 254, 254],
#           ...,
#           [221, 221, 221],
#           [222, 222, 222],
#           [220, 220, 220]],
#
#          [[249, 249, 249],
#           [252, 252, 252],
#           [254, 254, 254],
#           ...,
#           [221, 221, 221],
#           [227, 227, 227],
#           [225, 225, 225]]], dtype=uint8),
#   0],
#  [array([[[  8,   9,  13],
#           [  1,   2,   6],
#           [  4,   6,   7],
#           ...,
#           [235, 234, 236],
#           [253, 252, 253],
#           [251, 250, 252]],
#
#          [[  8,   9,  12],
#           [  6,   8,  10],
#           [  5,   8,   8],
#           ...,
#           [236, 240, 241],
#           [239, 243, 244],
#           [240, 244, 245]],
#
#          [[ 11,  13,  14],
#           [ 12,  14,  15],
#           [ 17,  19,  20],
#           ...,
#           [217, 226, 226],
#           [232, 241, 241],
#           [234, 243, 243]],
#
#          ...,
#
#          [[ 11,  10,  10],
#           [ 21,  20,  20],
#           [ 22,  22,  22],
#           ...,
#           [ 88,  79,  79],
#           [123, 111, 109],
#           [226, 215, 210]],
#
#          [[ 11,   5,   6],
#           [  9,   4,   5],
#           [  3,   1,   1],
#           ...,
#           [ 67,  59,  60],
#           [ 90,  80,  80],
#           [192, 180, 177]],
#
#          [[ 10,   2,   3],
#           [  9,   2,   3],
#           [ 10,   5,   6],
#           ...,
#           [ 22,  15,  18],
#           [ 77,  68,  68],
#           [145, 133, 130]]], dtype=uint8),
#   0],
#  [array([[[ 28,  62,  92],
#           [ 33,  65,  94],
#           [ 41,  71,  97],
#           ...,
#           [ 56,  59,  50],
#           [ 59,  62,  53],
#           [ 59,  62,  53]],
#
#          [[ 20,  52,  88],
#           [ 24,  56,  90],
#           [ 29,  61,  92],
#           ...,
#           [ 55,  58,  49],
#           [ 57,  60,  51],
#           [ 58,  61,  52]],
#
#          [[ 28,  58,  97],
#           [ 24,  56,  92],
#           [ 22,  54,  89],
#           ...,
#           [ 55,  58,  49],
#           [ 55,  58,  49],
#           [ 55,  58,  49]],
#
#          ...,
#
#          [[112, 136, 188],
#           [114, 137, 187],
#           [112, 135, 182],
#           ...,
#           [ 84,  30,   7],
#           [ 77,  23,   1],
#           [ 83,  28,   5]],
#
#          [[115, 139, 193],
#           [118, 140, 192],
#           [117, 140, 189],
#           ...,
#           [ 80,  26,   3],
#           [ 84,  30,   7],
#           [ 92,  37,  15]],
#
#          [[114, 138, 192],
#           [115, 136, 191],
#           [110, 132, 183],
#           ...,
#           [ 86,  32,   9],
#           [ 82,  28,   5],
#           [ 80,  25,   4]]], dtype=uint8),
#   0],
#  [array([[[255, 254,  72],
#           [255, 254,  72],
#           [255, 254,  72],
#           ...,
#           [255, 254, 132],
#           [255, 254, 132],
#           [255, 254, 132]],
#
#          [[254, 253,  71],
#           [254, 253,  71],
#           [254, 253,  71],
#           ...,
#           [255, 254, 132],
#           [255, 254, 132],
#           [255, 254, 132]],
#
#          [[253, 252,  70],
#           [253, 252,  70],
#           [253, 252,  70],
#           ...,
#           [255, 254, 132],
#           [255, 254, 132],
#           [255, 254, 132]],
#
#          ...,
#
#          [[215, 223, 106],
#           [227, 237, 116],
#           [230, 240, 124],
#           ...,
#           [222, 227, 140],
#           [221, 226, 146],
#           [221, 225, 150]],
#
#          [[224, 233, 106],
#           [234, 241, 123],
#           [235, 240, 138],
#           ...,
#           [172, 178,  91],
#           [158, 162,  82],
#           [155, 159,  84]],
#
#          [[234, 243, 110],
#           [243, 249, 135],
#           [241, 242, 155],
#           ...,
#           [254, 254, 172],
#           [249, 252, 171],
#           [252, 253, 181]]], dtype=uint8),
#   0],
#  [array([[[135, 132, 141],
#           [139, 136, 145],
#           [146, 143, 152],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[133, 130, 139],
#           [135, 132, 141],
#           [142, 139, 148],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[126, 124, 130],
#           [127, 125, 131],
#           [133, 131, 137],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[181, 180, 192],
#           [178, 176, 188],
#           [159, 158, 170],
#           ...,
#           [168, 160, 162],
#           [167, 159, 161],
#           [166, 157, 160]],
#
#          [[173, 173, 185],
#           [153, 153, 165],
#           [159, 159, 171],
#           ...,
#           [162, 154, 161],
#           [163, 155, 162],
#           [168, 157, 165]],
#
#          [[142, 142, 154],
#           [158, 158, 170],
#           [163, 163, 175],
#           ...,
#           [166, 158, 165],
#           [164, 156, 163],
#           [166, 155, 163]]], dtype=uint8),
#   0],
#  [array([[[ 50,  45,  40],
#           [253, 231, 200],
#           [248, 230, 198],
#           ...,
#           [ 65,  58,  62],
#           [ 63,  56,  61],
#           [ 63,  54,  64]],
#
#          [[145, 149, 143],
#           [242, 227, 194],
#           [238, 228, 193],
#           ...,
#           [ 67,  60,  65],
#           [ 64,  57,  62],
#           [ 64,  55,  65]],
#
#          [[130, 142, 133],
#           [233, 227, 191],
#           [231, 230, 191],
#           ...,
#           [ 72,  64,  71],
#           [ 63,  55,  62],
#           [ 65,  56,  66]],
#
#          ...,
#
#          [[184, 161, 183],
#           [185, 163, 184],
#           [169, 147, 165],
#           ...,
#           [127, 108, 127],
#           [170, 151, 170],
#           [147, 124, 146]],
#
#          [[165, 142, 164],
#           [181, 158, 179],
#           [175, 153, 171],
#           ...,
#           [150, 131, 150],
#           [171, 152, 171],
#           [140, 117, 139]],
#
#          [[183, 161, 181],
#           [173, 151, 171],
#           [183, 161, 180],
#           ...,
#           [153, 134, 154],
#           [159, 140, 160],
#           [170, 147, 168]]], dtype=uint8),
#   0],
#  [array([[[124, 118, 104],
#           [ 50,  35,  30],
#           [ 75,  54,  57],
#           ...,
#           [162, 190, 167],
#           [145, 173, 148],
#           [183, 194, 193]],
#
#          [[ 59,  51,  43],
#           [ 51,  35,  34],
#           [136, 115, 118],
#           ...,
#           [150, 175, 155],
#           [144, 185, 161],
#           [168, 177, 173]],
#
#          [[ 74,  63,  63],
#           [ 65,  47,  50],
#           [103,  82,  85],
#           ...,
#           [145, 164, 149],
#           [108, 161, 140],
#           [156, 163, 156]],
#
#          ...,
#
#          [[ 19,  31,  24],
#           [ 83,  91,  83],
#           [ 46,  47,  40],
#           ...,
#           [141, 142, 151],
#           [118, 117, 127],
#           [120, 119, 133]],
#
#          [[ 27,  27,  27],
#           [ 10,  10,  10],
#           [ 11,  11,  11],
#           ...,
#           [145, 144, 154],
#           [138, 136, 148],
#           [153, 151, 157]],
#
#          [[ 13,  13,  13],
#           [ 16,  16,  16],
#           [ 12,  12,  12],
#           ...,
#           [151, 150, 160],
#           [153, 151, 163],
#           [149, 145, 158]]], dtype=uint8),
#   0],
#  [array([[[ 31, 153,  86],
#           [ 42, 165, 110],
#           [ 53, 187, 120],
#           ...,
#           [142, 162,  84],
#           [153, 174,  61],
#           [138, 160,  56]],
#
#          [[ 28, 157,  86],
#           [ 42, 165, 107],
#           [ 54, 183, 115],
#           ...,
#           [140, 159,  85],
#           [155, 173,  68],
#           [151, 175,  47]],
#
#          [[ 25, 161,  90],
#           [ 42, 168, 111],
#           [ 54, 185, 117],
#           ...,
#           [140, 164,  75],
#           [151, 173,  56],
#           [153, 179,  40]],
#
#          ...,
#
#          [[ 57,  59,  60],
#           [ 55,  57,  58],
#           [ 52,  54,  55],
#           ...,
#           [128, 131, 136],
#           [125, 128, 133],
#           [126, 129, 134]],
#
#          [[ 52,  54,  55],
#           [ 50,  52,  53],
#           [ 52,  54,  55],
#           ...,
#           [132, 136, 141],
#           [130, 132, 137],
#           [125, 128, 133]],
#
#          [[ 50,  51,  53],
#           [ 47,  49,  50],
#           [ 50,  51,  53],
#           ...,
#           [127, 130, 135],
#           [127, 130, 135],
#           [129, 132, 137]]], dtype=uint8),
#   0],
#  [array([[[ 60,  55,  54],
#           [ 64,  59,  58],
#           [ 67,  61,  60],
#           ...,
#           [143, 138, 137],
#           [141, 136, 135],
#           [140, 135, 134]],
#
#          [[ 65,  60,  59],
#           [ 70,  65,  64],
#           [ 72,  67,  66],
#           ...,
#           [128, 123, 122],
#           [126, 121, 120],
#           [124, 119, 118]],
#
#          [[ 82,  78,  77],
#           [ 86,  83,  82],
#           [ 89,  85,  84],
#           ...,
#           [116, 111, 110],
#           [114, 108, 108],
#           [111, 107, 105]],
#
#          ...,
#
#          [[ 22,  25,  23],
#           [ 22,  25,  23],
#           [ 22,  25,  23],
#           ...,
#           [126, 121, 120],
#           [125, 120, 119],
#           [107, 102, 101]],
#
#          [[ 20,  23,  21],
#           [ 20,  23,  21],
#           [ 20,  23,  21],
#           ...,
#           [130, 125, 124],
#           [107, 102, 100],
#           [101,  96,  95]],
#
#          [[ 18,  21,  19],
#           [ 18,  21,  19],
#           [ 18,  21,  19],
#           ...,
#           [127, 122, 121],
#           [107, 102, 101],
#           [104,  98,  98]]], dtype=uint8),
#   0],
#  [array([[[ 13,  28,  47],
#           [ 11,  26,  45],
#           [ 12,  27,  46],
#           ...,
#           [ 41,  64,  86],
#           [ 44,  67,  89],
#           [ 47,  66,  93]],
#
#          [[ 14,  28,  46],
#           [ 12,  26,  44],
#           [ 12,  26,  44],
#           ...,
#           [ 42,  65,  87],
#           [ 44,  68,  90],
#           [ 46,  67,  88]],
#
#          [[ 15,  29,  45],
#           [ 13,  27,  43],
#           [ 13,  26,  42],
#           ...,
#           [ 43,  66,  88],
#           [ 46,  69,  91],
#           [ 47,  70,  87]],
#
#          ...,
#
#          [[ 27,  40,  55],
#           [ 38,  54,  63],
#           [ 30,  46,  52],
#           ...,
#           [ 33,  41,  48],
#           [ 30,  37,  42],
#           [ 26,  38,  41]],
#
#          [[ 66,  84, 105],
#           [ 74,  94, 109],
#           [ 49,  70,  82],
#           ...,
#           [ 42,  50,  57],
#           [ 38,  46,  50],
#           [ 32,  43,  47]],
#
#          [[ 64,  87, 114],
#           [ 74,  99, 120],
#           [ 76, 102, 120],
#           ...,
#           [ 42,  50,  57],
#           [ 42,  49,  54],
#           [ 35,  46,  50]]], dtype=uint8),
#   0],
#  [array([[[183, 188, 195],
#           [188, 194, 201],
#           [195, 201, 208],
#           ...,
#           [ 77,  95, 112],
#           [ 77,  95, 112],
#           [ 77,  95, 112]],
#
#          [[183, 189, 196],
#           [189, 195, 202],
#           [195, 201, 208],
#           ...,
#           [ 78,  96, 113],
#           [ 78,  96, 113],
#           [ 78,  96, 113]],
#
#          [[184, 190, 197],
#           [190, 196, 203],
#           [196, 202, 209],
#           ...,
#           [ 79,  97, 114],
#           [ 79,  97, 114],
#           [ 79,  97, 114]],
#
#          ...,
#
#          [[197, 187, 200],
#           [203, 190, 204],
#           [204, 188, 203],
#           ...,
#           [155, 154, 173],
#           [143, 172, 199],
#           [139, 186, 219]],
#
#          [[204, 193, 206],
#           [214, 197, 211],
#           [213, 191, 207],
#           ...,
#           [154, 162, 185],
#           [146, 181, 214],
#           [144, 197, 235]],
#
#          [[205, 194, 207],
#           [207, 189, 204],
#           [212, 186, 202],
#           ...,
#           [150, 166, 192],
#           [141, 183, 219],
#           [140, 197, 240]]], dtype=uint8),
#   0],
#  [array([[[100, 105,  96],
#           [100, 105,  96],
#           [100, 105,  96],
#           ...,
#           [ 86,  92,  87],
#           [ 85,  91,  86],
#           [ 84,  90,  85]],
#
#          [[100, 105,  96],
#           [100, 105,  96],
#           [100, 105,  96],
#           ...,
#           [ 86,  92,  87],
#           [ 85,  91,  86],
#           [ 85,  91,  86]],
#
#          [[100, 104,  98],
#           [100, 104,  98],
#           [100, 104,  98],
#           ...,
#           [ 87,  93,  88],
#           [ 86,  92,  87],
#           [ 86,  92,  87]],
#
#          ...,
#
#          [[ 35,  82, 106],
#           [ 35,  82, 104],
#           [ 39,  84, 107],
#           ...,
#           [  1,   1,   1],
#           [  1,   1,   1],
#           [  1,   1,   1]],
#
#          [[ 39,  86, 110],
#           [ 29,  76,  98],
#           [ 32,  77, 100],
#           ...,
#           [  1,   1,   1],
#           [  1,   1,   1],
#           [  1,   1,   1]],
#
#          [[ 38,  85, 109],
#           [ 33,  80, 102],
#           [ 23,  69,  91],
#           ...,
#           [  1,   1,   1],
#           [  1,   1,   1],
#           [  1,   1,   1]]], dtype=uint8),
#   0],
#  [array([[[34, 48, 44],
#           [35, 49, 45],
#           [34, 48, 44],
#           ...,
#           [ 0,  5,  6],
#           [ 1, 10, 18],
#           [ 3, 15, 21]],
#
#          [[49, 62, 60],
#           [51, 64, 62],
#           [52, 65, 63],
#           ...,
#           [ 2,  6,  6],
#           [ 4, 12, 19],
#           [ 4, 16, 22]],
#
#          [[50, 64, 63],
#           [49, 63, 62],
#           [54, 68, 67],
#           ...,
#           [ 6,  7,  6],
#           [ 9, 15, 18],
#           [ 5, 17, 23]],
#
#          ...,
#
#          [[ 2, 13, 17],
#           [ 2, 13, 17],
#           [ 3, 14, 18],
#           ...,
#           [98, 74, 45],
#           [86, 62, 41],
#           [47, 41, 22]],
#
#          [[ 1, 12, 16],
#           [ 1, 12, 16],
#           [ 1, 12, 16],
#           ...,
#           [95, 71, 42],
#           [87, 63, 42],
#           [55, 49, 30]],
#
#          [[ 0, 11, 15],
#           [ 0, 11, 15],
#           [ 1, 12, 16],
#           ...,
#           [95, 71, 42],
#           [93, 69, 48],
#           [57, 51, 32]]], dtype=uint8),
#   0],
#  [array([[[164, 163, 175],
#           [127, 164, 158],
#           [ 84, 155, 132],
#           ...,
#           [171, 178, 135],
#           [173, 180, 137],
#           [183, 179, 138]],
#
#          [[166, 173, 181],
#           [122, 163, 154],
#           [ 89, 161, 136],
#           ...,
#           [171, 178, 135],
#           [166, 173, 130],
#           [172, 171, 129]],
#
#          [[154, 175, 176],
#           [113, 162, 149],
#           [ 86, 159, 134],
#           ...,
#           [172, 179, 136],
#           [180, 187, 144],
#           [182, 184, 142]],
#
#          ...,
#
#          [[ 63,  57,  47],
#           [ 56,  56,  45],
#           [ 53,  58,  46],
#           ...,
#           [100, 142, 204],
#           [100, 138, 197],
#           [100, 145, 198]],
#
#          [[ 47,  48,  39],
#           [ 43,  49,  37],
#           [ 39,  46,  33],
#           ...,
#           [ 90, 132, 199],
#           [111, 138, 194],
#           [117, 148, 203]],
#
#          [[ 30,  31,  22],
#           [ 27,  33,  21],
#           [ 27,  34,  21],
#           ...,
#           [ 94, 139, 201],
#           [106, 140, 188],
#           [ 92, 123, 178]]], dtype=uint8),
#   0],
#  [array([[[117, 130, 144],
#           [120, 133, 147],
#           [111, 124, 138],
#           ...,
#           [103, 112, 126],
#           [ 95, 103, 117],
#           [106, 115, 129]],
#
#          [[125, 138, 152],
#           [125, 138, 152],
#           [115, 128, 142],
#           ...,
#           [101, 110, 124],
#           [ 87,  96, 110],
#           [ 97, 106, 120]],
#
#          [[119, 131, 145],
#           [129, 142, 156],
#           [116, 129, 143],
#           ...,
#           [100, 109, 123],
#           [ 90,  99, 113],
#           [ 89,  98, 112]],
#
#          ...,
#
#          [[ 24,  27,  31],
#           [ 29,  32,  36],
#           [ 32,  35,  40],
#           ...,
#           [140, 155, 172],
#           [154, 169, 188],
#           [174, 187, 207]],
#
#          [[ 25,  28,  32],
#           [ 27,  30,  34],
#           [ 28,  31,  36],
#           ...,
#           [140, 156, 173],
#           [145, 160, 179],
#           [159, 172, 192]],
#
#          [[ 26,  29,  33],
#           [ 23,  27,  30],
#           [ 24,  27,  32],
#           ...,
#           [158, 173, 190],
#           [146, 161, 180],
#           [155, 169, 189]]], dtype=uint8),
#   0],
#  [array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [ 31,  30,   9],
#           [ 30,  28,   8],
#           [ 33,  32,  11]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [ 37,  36,  15],
#           [ 34,  33,  12],
#           [ 34,  33,  12]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [ 40,  39,  18],
#           [ 39,  38,  17],
#           [ 38,  37,  16]],
#
#          ...,
#
#          [[131, 126, 121],
#           [137, 136, 137],
#           [142, 149, 158],
#           ...,
#           [ 39,  37,  13],
#           [ 38,  36,  12],
#           [ 38,  36,  12]],
#
#          [[134, 131, 128],
#           [149, 151, 153],
#           [141, 150, 160],
#           ...,
#           [ 40,  38,  14],
#           [ 39,  38,  13],
#           [ 40,  38,  14]],
#
#          [[108, 109, 110],
#           [153, 157, 163],
#           [133, 143, 156],
#           ...,
#           [ 41,  39,  15],
#           [ 42,  39,  15],
#           [ 44,  41,  18]]], dtype=uint8),
#   0],
#  [array([[[255, 253, 253],
#           [255, 255, 254],
#           [255, 254, 253],
#           ...,
#           [201, 186, 184],
#           [197, 182, 180],
#           [200, 185, 183]],
#
#          [[255, 254, 253],
#           [255, 255, 254],
#           [255, 255, 253],
#           ...,
#           [202, 187, 185],
#           [197, 182, 180],
#           [200, 185, 183]],
#
#          [[255, 254, 253],
#           [255, 254, 253],
#           [255, 254, 253],
#           ...,
#           [206, 191, 189],
#           [201, 186, 184],
#           [199, 184, 182]],
#
#          ...,
#
#          [[167, 182, 178],
#           [164, 179, 175],
#           [160, 175, 171],
#           ...,
#           [144, 166, 163],
#           [144, 165, 162],
#           [144, 165, 162]],
#
#          [[164, 179, 175],
#           [166, 181, 177],
#           [162, 177, 173],
#           ...,
#           [143, 164, 162],
#           [144, 165, 162],
#           [144, 165, 162]],
#
#          [[163, 180, 169],
#           [164, 181, 170],
#           [163, 180, 171],
#           ...,
#           [143, 165, 161],
#           [147, 168, 165],
#           [142, 163, 160]]], dtype=uint8),
#   0],
#  [array([[[192, 219, 236],
#           [189, 217, 234],
#           [184, 212, 229],
#           ...,
#           [146, 176, 187],
#           [146, 176, 187],
#           [144, 173, 187]],
#
#          [[183, 211, 228],
#           [180, 208, 225],
#           [178, 206, 223],
#           ...,
#           [150, 180, 191],
#           [150, 180, 191],
#           [147, 176, 190]],
#
#          [[182, 210, 227],
#           [178, 206, 223],
#           [173, 201, 218],
#           ...,
#           [152, 182, 194],
#           [152, 182, 194],
#           [151, 180, 194]],
#
#          ...,
#
#          [[111,  57,  34],
#           [113,  59,  36],
#           [120,  66,  43],
#           ...,
#           [ 81,  83,  82],
#           [ 80,  82,  81],
#           [ 98,  98, 105]],
#
#          [[110,  56,  33],
#           [114,  60,  37],
#           [119,  65,  42],
#           ...,
#           [ 98,  98,  98],
#           [ 92,  92,  92],
#           [ 96,  92, 102]],
#
#          [[111,  57,  34],
#           [113,  58,  35],
#           [114,  60,  37],
#           ...,
#           [ 89,  89,  89],
#           [ 89,  89,  89],
#           [114, 115, 113]]], dtype=uint8),
#   0],
#  [array([[[ 12,  17,  15],
#           [ 16,  21,  18],
#           [ 13,  18,  16],
#           ...,
#           [ 90, 115, 131],
#           [ 90, 115, 131],
#           [ 90, 115, 131]],
#
#          [[ 22,  27,  26],
#           [ 26,  31,  29],
#           [ 23,  28,  28],
#           ...,
#           [ 90, 115, 131],
#           [ 90, 115, 131],
#           [ 90, 115, 131]],
#
#          [[ 30,  36,  35],
#           [ 34,  40,  39],
#           [ 32,  38,  37],
#           ...,
#           [ 90, 115, 131],
#           [ 90, 115, 131],
#           [ 90, 115, 131]],
#
#          ...,
#
#          [[ 42,  40,  39],
#           [ 36,  36,  36],
#           [ 33,  34,  34],
#           ...,
#           [ 56,  64,  64],
#           [ 36,  41,  42],
#           [ 25,  30,  31]],
#
#          [[ 43,  41,  40],
#           [ 38,  38,  38],
#           [ 34,  35,  35],
#           ...,
#           [ 42,  50,  50],
#           [ 45,  50,  51],
#           [ 31,  35,  36]],
#
#          [[ 42,  40,  39],
#           [ 39,  39,  39],
#           [ 36,  37,  37],
#           ...,
#           [ 38,  46,  46],
#           [ 39,  44,  45],
#           [ 45,  50,  51]]], dtype=uint8),
#   0],
#  [array([[[ 85,  82,  91],
#           [ 86,  83,  92],
#           [ 87,  84,  94],
#           ...,
#           [ 66,  85, 111],
#           [ 66,  87, 108],
#           [ 62,  72,  72]],
#
#          [[ 86,  83,  92],
#           [ 87,  84,  93],
#           [ 88,  85,  94],
#           ...,
#           [ 79,  98, 116],
#           [ 62,  81,  94],
#           [ 68,  76,  76]],
#
#          [[ 87,  84,  93],
#           [ 88,  85,  94],
#           [ 88,  85,  94],
#           ...,
#           [ 91, 105, 116],
#           [ 77,  92,  96],
#           [ 74,  79,  78]],
#
#          ...,
#
#          [[ 20,  42,  73],
#           [ 26,  45,  76],
#           [ 40,  58,  91],
#           ...,
#           [ 42,  33,  73],
#           [ 40,  31,  71],
#           [ 36,  32,  68]],
#
#          [[ 28,  57,  94],
#           [ 31,  57,  94],
#           [ 32,  56,  92],
#           ...,
#           [ 40,  31,  71],
#           [ 37,  28,  68],
#           [ 35,  31,  67]],
#
#          [[ 34,  72, 114],
#           [ 39,  70, 113],
#           [ 37,  66, 106],
#           ...,
#           [ 39,  30,  70],
#           [ 36,  27,  67],
#           [ 33,  29,  65]]], dtype=uint8),
#   0],
#  [array([[[160, 160, 160],
#           [153, 153, 153],
#           [148, 148, 148],
#           ...,
#           [ 96,  73, 155],
#           [100,  75, 163],
#           [ 90,  71, 158]],
#
#          [[158, 158, 158],
#           [142, 142, 142],
#           [149, 149, 149],
#           ...,
#           [ 95,  71, 154],
#           [ 94,  68, 157],
#           [ 87,  68, 156]],
#
#          [[164, 164, 164],
#           [152, 152, 152],
#           [148, 148, 148],
#           ...,
#           [ 93,  69, 153],
#           [ 90,  63, 154],
#           [ 84,  64, 153]],
#
#          ...,
#
#          [[ 10,  10,  10],
#           [ 13,  13,  13],
#           [ 25,  25,  25],
#           ...,
#           [157, 160, 163],
#           [152, 156, 160],
#           [113, 116, 114]],
#
#          [[ 13,  15,  15],
#           [ 18,  20,  20],
#           [ 23,  25,  25],
#           ...,
#           [ 74,  74,  74],
#           [ 79,  82,  86],
#           [ 89,  94,  92]],
#
#          [[ 16,  18,  18],
#           [ 24,  26,  26],
#           [ 24,  26,  26],
#           ...,
#           [ 66,  66,  66],
#           [ 53,  56,  60],
#           [ 84,  89,  87]]], dtype=uint8),
#   0],
#  [array([[[188, 132, 162],
#           [212, 143, 177],
#           [213, 145, 178],
#           ...,
#           [227, 203, 205],
#           [233, 209, 194],
#           [233, 202, 197]],
#
#          [[188, 140, 164],
#           [195, 138, 166],
#           [203, 147, 173],
#           ...,
#           [229, 199, 194],
#           [209, 177, 156],
#           [212, 172, 163]],
#
#          [[196, 158, 176],
#           [188, 144, 164],
#           [195, 159, 172],
#           ...,
#           [200, 163, 144],
#           [160, 116,  86],
#           [165, 109,  97]],
#
#          ...,
#
#          [[220, 204, 197],
#           [223, 207, 200],
#           [226, 210, 203],
#           ...,
#           [250, 232, 225],
#           [242, 225, 218],
#           [240, 226, 219]],
#
#          [[205, 189, 182],
#           [210, 194, 187],
#           [217, 201, 194],
#           ...,
#           [248, 230, 223],
#           [244, 228, 221],
#           [246, 233, 225]],
#
#          [[212, 196, 189],
#           [215, 199, 192],
#           [219, 203, 196],
#           ...,
#           [248, 230, 223],
#           [248, 231, 224],
#           [248, 235, 227]]], dtype=uint8),
#   0],
#  [array([[[255, 255, 246],
#           [255, 255, 249],
#           [253, 254, 253],
#           ...,
#           [ 94, 107, 137],
#           [114, 126, 166],
#           [124, 136, 176]],
#
#          [[184, 179, 194],
#           [157, 157, 181],
#           [134, 141, 169],
#           ...,
#           [104, 120, 151],
#           [113, 125, 156],
#           [126, 138, 169]],
#
#          [[104, 107, 146],
#           [101, 112, 155],
#           [ 95, 115, 163],
#           ...,
#           [ 89, 108, 141],
#           [ 94, 118, 150],
#           [ 98, 122, 154]],
#
#          ...,
#
#          [[128, 159, 198],
#           [135, 167, 203],
#           [116, 151, 185],
#           ...,
#           [  3,   0,  22],
#           [  2,   2,  19],
#           [  1,   1,  19]],
#
#          [[151, 187, 224],
#           [147, 180, 214],
#           [145, 176, 208],
#           ...,
#           [  3,   0,  25],
#           [  0,   0,  24],
#           [  0,   0,  25]],
#
#          [[120, 160, 195],
#           [149, 182, 215],
#           [164, 192, 223],
#           ...,
#           [  2,   0,  26],
#           [  0,   1,  29],
#           [  1,   2,  30]]], dtype=uint8),
#   0],
#  [array([[[156, 167, 203],
#           [191, 188, 202],
#           [235, 219, 213],
#           ...,
#           [104, 117,  39],
#           [110, 116,  39],
#           [115, 121,  42]],
#
#          [[153, 163, 202],
#           [167, 165, 181],
#           [227, 213, 207],
#           ...,
#           [103, 116,  38],
#           [111, 117,  40],
#           [106, 117,  37]],
#
#          [[139, 151, 192],
#           [141, 140, 162],
#           [224, 210, 212],
#           ...,
#           [101, 113,  37],
#           [107, 112,  37],
#           [ 99, 114,  33]],
#
#          ...,
#
#          [[153, 164, 191],
#           [123, 134, 161],
#           [104, 113, 146],
#           ...,
#           [104,  77, 126],
#           [112,  83, 127],
#           [112,  92, 135]],
#
#          [[135, 149, 171],
#           [114, 123, 151],
#           [116, 126, 160],
#           ...,
#           [105,  84, 131],
#           [102,  77, 120],
#           [105,  80, 140]],
#
#          [[164, 182, 198],
#           [120, 121, 153],
#           [127, 137, 175],
#           ...,
#           [129, 121, 162],
#           [103,  86, 125],
#           [ 97,  75, 124]]], dtype=uint8),
#   0],
#  [array([[[142, 148, 153],
#           [148, 154, 159],
#           [152, 158, 163],
#           ...,
#           [ 60,  64,  54],
#           [ 36,  35,  36],
#           [ 39,  37,  36]],
#
#          [[145, 151, 156],
#           [150, 156, 161],
#           [154, 160, 165],
#           ...,
#           [ 61,  64,  55],
#           [ 48,  49,  48],
#           [ 48,  49,  47]],
#
#          [[149, 155, 160],
#           [151, 157, 162],
#           [153, 159, 164],
#           ...,
#           [ 53,  55,  48],
#           [ 52,  53,  49],
#           [ 49,  52,  50]],
#
#          ...,
#
#          [[ 91,  96,  95],
#           [ 92,  97,  96],
#           [ 91,  96,  95],
#           ...,
#           [115, 125, 137],
#           [136, 150, 167],
#           [159, 171, 175]],
#
#          [[ 89,  94,  93],
#           [ 91,  96,  95],
#           [ 91,  96,  95],
#           ...,
#           [123, 135, 142],
#           [142, 157, 168],
#           [146, 157, 166]],
#
#          [[ 87,  92,  91],
#           [ 91,  96,  95],
#           [ 91,  96,  95],
#           ...,
#           [133, 146, 147],
#           [134, 148, 152],
#           [137, 146, 160]]], dtype=uint8),
#   0],
#  [array([[[156, 157, 153],
#           [158, 159, 155],
#           [155, 156, 152],
#           ...,
#           [169, 170, 168],
#           [171, 172, 170],
#           [169, 170, 166]],
#
#          [[152, 153, 149],
#           [153, 154, 150],
#           [154, 155, 150],
#           ...,
#           [170, 171, 169],
#           [169, 170, 168],
#           [171, 172, 168]],
#
#          [[156, 157, 153],
#           [157, 158, 154],
#           [157, 158, 154],
#           ...,
#           [170, 171, 170],
#           [168, 169, 167],
#           [169, 170, 166]],
#
#          ...,
#
#          [[ 82,  90,  89],
#           [ 63,  71,  70],
#           [ 63,  71,  70],
#           ...,
#           [162, 162, 162],
#           [171, 170, 170],
#           [164, 169, 168]],
#
#          [[117, 123, 122],
#           [109, 115, 114],
#           [101, 107, 106],
#           ...,
#           [148, 143, 144],
#           [154, 148, 149],
#           [148, 153, 153]],
#
#          [[109, 114, 114],
#           [114, 118, 118],
#           [103, 108, 107],
#           ...,
#           [167, 165, 164],
#           [166, 164, 163],
#           [185, 183, 183]]], dtype=uint8),
#   0],
#  [array([[[193, 212, 195],
#           [173, 171, 157],
#           [199, 181, 170],
#           ...,
#           [ 87, 111, 127],
#           [ 43,  51,  70],
#           [  8,  33,  44]],
#
#          [[146, 158, 142],
#           [155, 150, 137],
#           [186, 171, 159],
#           ...,
#           [ 92, 118, 140],
#           [ 88, 102, 126],
#           [ 24,  36,  56]],
#
#          [[204, 205, 190],
#           [182, 175, 162],
#           [222, 213, 200],
#           ...,
#           [ 97, 126, 155],
#           [ 93, 113, 143],
#           [ 73,  83, 110]],
#
#          ...,
#
#          [[139, 128, 115],
#           [128, 129, 121],
#           [121, 128, 124],
#           ...,
#           [ 49,  84, 105],
#           [ 57,  92, 113],
#           [ 59,  86, 111]],
#
#          [[112, 104,  97],
#           [136, 125, 116],
#           [131, 121, 111],
#           ...,
#           [ 54,  89, 112],
#           [ 46,  83, 105],
#           [ 50,  84, 104]],
#
#          [[119, 111, 104],
#           [121, 111, 102],
#           [130, 120, 110],
#           ...,
#           [ 49,  84, 107],
#           [ 46,  82, 104],
#           [ 46,  79,  99]]], dtype=uint8),
#   0],
#  [array([[[ 43,  76, 109],
#           [ 46,  79, 112],
#           [ 45,  78, 111],
#           ...,
#           [116, 118, 105],
#           [ 73,  71,  65],
#           [ 15,  18,  16]],
#
#          [[ 46,  77, 110],
#           [ 48,  79, 112],
#           [ 50,  81, 114],
#           ...,
#           [114, 116, 104],
#           [ 88,  85,  81],
#           [ 25,  25,  25]],
#
#          [[ 45,  76, 107],
#           [ 47,  78, 109],
#           [ 46,  77, 108],
#           ...,
#           [124, 125, 116],
#           [120, 116, 116],
#           [ 32,  30,  32]],
#
#          ...,
#
#          [[ 39,  56,  75],
#           [ 87, 110, 128],
#           [103, 129, 146],
#           ...,
#           [ 34,  41,  56],
#           [ 51,  58,  73],
#           [ 37,  44,  59]],
#
#          [[ 85, 102, 121],
#           [ 97, 120, 138],
#           [107, 133, 150],
#           ...,
#           [ 38,  45,  60],
#           [ 44,  51,  66],
#           [ 43,  50,  65]],
#
#          [[100, 117, 136],
#           [ 99, 122, 140],
#           [110, 136, 153],
#           ...,
#           [ 39,  46,  61],
#           [ 47,  54,  69],
#           [ 40,  47,  62]]], dtype=uint8),
#   0],
#  [array([[[ 68,  79,  83],
#           [133, 141, 142],
#           [143, 147, 145],
#           ...,
#           [137, 139, 139],
#           [130, 135, 134],
#           [136, 136, 136]],
#
#          [[ 23,  34,  38],
#           [ 83,  91,  94],
#           [135, 140, 138],
#           ...,
#           [137, 140, 140],
#           [131, 136, 135],
#           [134, 134, 134]],
#
#          [[ 27,  39,  45],
#           [ 31,  40,  43],
#           [ 96, 101, 100],
#           ...,
#           [138, 141, 141],
#           [132, 137, 136],
#           [131, 131, 131]],
#
#          ...,
#
#          [[140, 143, 148],
#           [144, 147, 152],
#           [148, 152, 157],
#           ...,
#           [ 34,  32, 155],
#           [ 34,  34, 150],
#           [ 37,  33, 159]],
#
#          [[145, 148, 153],
#           [141, 144, 149],
#           [136, 139, 144],
#           ...,
#           [ 32,  32, 149],
#           [ 33,  29, 154],
#           [ 36,  32, 158]],
#
#          [[137, 140, 145],
#           [137, 140, 145],
#           [139, 142, 147],
#           ...,
#           [ 30,  34, 145],
#           [ 37,  27, 159],
#           [ 34,  30, 156]]], dtype=uint8),
#   0],
#  [array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[150, 227, 243],
#           [154, 233, 246],
#           [156, 235, 246],
#           ...,
#           [227, 249, 255],
#           [225, 251, 254],
#           [212, 240, 250]],
#
#          [[152, 230, 243],
#           [157, 236, 247],
#           [160, 237, 246],
#           ...,
#           [182, 205, 227],
#           [173, 192, 224],
#           [178, 192, 228]],
#
#          [[155, 234, 245],
#           [161, 239, 248],
#           [165, 240, 248],
#           ...,
#           [157, 179, 214],
#           [144, 154, 204],
#           [173, 172, 231]]], dtype=uint8),
#   0],
#  [array([[[219, 211, 198],
#           [220, 212, 199],
#           [220, 212, 199],
#           ...,
#           [ 84, 134, 149],
#           [ 89, 139, 155],
#           [ 97, 147, 162]],
#
#          [[219, 211, 198],
#           [220, 212, 199],
#           [220, 212, 199],
#           ...,
#           [ 87, 131, 144],
#           [ 89, 134, 147],
#           [ 97, 141, 154]],
#
#          [[219, 211, 198],
#           [220, 212, 199],
#           [220, 212, 199],
#           ...,
#           [ 97, 132, 142],
#           [ 99, 134, 143],
#           [ 84, 119, 129]],
#
#          ...,
#
#          [[114, 155, 148],
#           [112, 153, 146],
#           [106, 147, 141],
#           ...,
#           [ 63,  96,  99],
#           [ 66,  99, 102],
#           [ 70, 103, 106]],
#
#          [[103, 145, 138],
#           [107, 149, 142],
#           [109, 151, 144],
#           ...,
#           [ 61,  93,  97],
#           [ 66,  99, 103],
#           [ 69, 103, 106]],
#
#          [[108, 150, 143],
#           [109, 151, 144],
#           [108, 151, 144],
#           ...,
#           [ 68, 101, 104],
#           [ 77, 110, 113],
#           [ 78, 111, 114]]], dtype=uint8),
#   0],
#  [array([[[118, 111, 114],
#           [152, 145, 148],
#           [151, 144, 147],
#           ...,
#           [ 82,  85,  90],
#           [ 82,  85,  90],
#           [ 92,  94,  95]],
#
#          [[102,  95,  98],
#           [149, 142, 145],
#           [154, 147, 150],
#           ...,
#           [ 82,  85,  90],
#           [ 82,  85,  90],
#           [ 95,  97,  98]],
#
#          [[ 81,  74,  77],
#           [153, 146, 149],
#           [154, 147, 150],
#           ...,
#           [ 82,  85,  90],
#           [ 82,  85,  90],
#           [103, 105, 106]],
#
#          ...,
#
#          [[ 44,  48,  48],
#           [ 43,  45,  45],
#           [ 69,  69,  69],
#           ...,
#           [199, 188, 192],
#           [196, 188, 193],
#           [197, 190, 193]],
#
#          [[ 45,  53,  52],
#           [ 49,  56,  55],
#           [ 55,  60,  59],
#           ...,
#           [206, 191, 195],
#           [203, 192, 195],
#           [200, 191, 194]],
#
#          [[ 43,  51,  50],
#           [ 49,  56,  55],
#           [ 52,  57,  56],
#           ...,
#           [209, 194, 198],
#           [206, 195, 198],
#           [205, 196, 199]]], dtype=uint8),
#   0],
#  [array([[[33, 37, 39],
#           [36, 40, 42],
#           [31, 35, 36],
#           ...,
#           [14, 17, 15],
#           [14, 17, 15],
#           [13, 15, 15]],
#
#          [[70, 73, 72],
#           [79, 82, 81],
#           [70, 73, 72],
#           ...,
#           [13, 16, 14],
#           [15, 18, 16],
#           [12, 14, 14]],
#
#          [[75, 80, 72],
#           [76, 80, 72],
#           [75, 80, 72],
#           ...,
#           [15, 19, 17],
#           [16, 19, 17],
#           [15, 17, 17]],
#
#          ...,
#
#          [[81, 87, 82],
#           [88, 94, 89],
#           [91, 97, 92],
#           ...,
#           [60, 65, 63],
#           [63, 68, 66],
#           [60, 66, 63]],
#
#          [[79, 85, 80],
#           [85, 91, 86],
#           [81, 87, 82],
#           ...,
#           [65, 70, 69],
#           [68, 72, 73],
#           [62, 72, 66]],
#
#          [[85, 91, 86],
#           [77, 83, 78],
#           [72, 78, 73],
#           ...,
#           [65, 70, 69],
#           [65, 69, 70],
#           [65, 74, 69]]], dtype=uint8),
#   0],
#  [array([[[214, 209, 206],
#           [213, 208, 205],
#           [215, 210, 207],
#           ...,
#           [109, 121, 121],
#           [105, 119, 118],
#           [108, 118, 118]],
#
#          [[205, 199, 197],
#           [213, 208, 205],
#           [214, 209, 206],
#           ...,
#           [110, 122, 122],
#           [106, 120, 119],
#           [106, 116, 116]],
#
#          [[207, 202, 199],
#           [216, 211, 208],
#           [214, 209, 206],
#           ...,
#           [111, 123, 123],
#           [107, 121, 120],
#           [108, 118, 118]],
#
#          ...,
#
#          [[124, 139, 153],
#           [116, 130, 147],
#           [130, 143, 163],
#           ...,
#           [104, 112, 113],
#           [120, 132, 134],
#           [101, 113, 127]],
#
#          [[103, 122, 130],
#           [122, 138, 153],
#           [142, 157, 175],
#           ...,
#           [ 82,  94, 100],
#           [108, 121, 131],
#           [ 99, 111, 124]],
#
#          [[ 92, 104, 113],
#           [103, 113, 129],
#           [117, 126, 144],
#           ...,
#           [ 79,  90,  96],
#           [ 74,  86,  94],
#           [ 86,  97, 104]]], dtype=uint8),
#   0],
#  [array([[[154, 220, 215],
#           [156, 229, 225],
#           [154, 225, 223],
#           ...,
#           [153, 207, 207],
#           [154, 206, 206],
#           [155, 201, 208]],
#
#          [[152, 217, 218],
#           [151, 225, 223],
#           [153, 224, 222],
#           ...,
#           [149, 203, 203],
#           [152, 203, 203],
#           [153, 203, 209]],
#
#          [[150, 212, 222],
#           [147, 220, 224],
#           [148, 222, 220],
#           ...,
#           [146, 200, 200],
#           [151, 203, 203],
#           [147, 201, 204]],
#
#          ...,
#
#          [[168, 201, 216],
#           [168, 201, 216],
#           [172, 205, 220],
#           ...,
#           [143, 175, 189],
#           [142, 176, 189],
#           [143, 173, 184]],
#
#          [[169, 201, 216],
#           [166, 199, 214],
#           [171, 204, 219],
#           ...,
#           [142, 175, 188],
#           [143, 177, 190],
#           [144, 175, 184]],
#
#          [[169, 202, 217],
#           [166, 199, 214],
#           [172, 204, 219],
#           ...,
#           [139, 172, 185],
#           [140, 174, 187],
#           [144, 176, 182]]], dtype=uint8),
#   0],
#  [array([[[ 32,  37,  35],
#           [ 32,  37,  35],
#           [ 32,  37,  35],
#           ...,
#           [ 43,  45,  45],
#           [ 44,  46,  46],
#           [ 44,  46,  46]],
#
#          [[ 34,  39,  37],
#           [ 34,  39,  37],
#           [ 34,  39,  37],
#           ...,
#           [ 45,  47,  47],
#           [ 46,  48,  48],
#           [ 46,  48,  48]],
#
#          [[ 37,  42,  40],
#           [ 37,  42,  40],
#           [ 37,  42,  40],
#           ...,
#           [ 45,  47,  47],
#           [ 44,  46,  46],
#           [ 46,  48,  48]],
#
#          ...,
#
#          [[ 15,  46,  79],
#           [ 15,  46,  79],
#           [ 15,  46,  79],
#           ...,
#           [188, 183, 165],
#           [199, 192, 175],
#           [210, 203, 186]],
#
#          [[ 14,  47,  72],
#           [ 14,  47,  72],
#           [ 14,  47,  72],
#           ...,
#           [194, 190, 172],
#           [202, 195, 178],
#           [208, 201, 184]],
#
#          [[ 34,  57,  73],
#           [ 23,  50,  63],
#           [ 18,  50,  61],
#           ...,
#           [208, 194, 184],
#           [204, 196, 183],
#           [205, 197, 184]]], dtype=uint8),
#   0],
#  [array([[[116, 137, 129],
#           [ 90, 111, 103],
#           [ 97, 118, 110],
#           ...,
#           [155, 164, 161],
#           [152, 161, 158],
#           [170, 179, 176]],
#
#          [[115, 136, 128],
#           [ 83, 104,  96],
#           [ 91, 112, 104],
#           ...,
#           [150, 159, 156],
#           [148, 157, 154],
#           [166, 175, 172]],
#
#          [[116, 137, 129],
#           [ 78,  99,  91],
#           [ 88, 109, 101],
#           ...,
#           [148, 157, 154],
#           [147, 156, 153],
#           [165, 174, 171]],
#
#          ...,
#
#          [[ 74,  69,  78],
#           [ 40,  37,  46],
#           [ 48,  45,  54],
#           ...,
#           [180, 149, 218],
#           [180, 150, 218],
#           [198, 167, 234]],
#
#          [[ 71,  66,  75],
#           [ 35,  32,  41],
#           [ 35,  32,  41],
#           ...,
#           [180, 145, 215],
#           [178, 144, 214],
#           [195, 162, 229]],
#
#          [[ 75,  70,  79],
#           [ 25,  22,  31],
#           [ 27,  24,  33],
#           ...,
#           [180, 146, 216],
#           [176, 141, 211],
#           [192, 159, 226]]], dtype=uint8),
#   0],
#  [array([[[131, 131, 131],
#           [131, 131, 131],
#           [131, 131, 131],
#           ...,
#           [154, 153, 149],
#           [151, 149, 148],
#           [151, 149, 149]],
#
#          [[131, 131, 131],
#           [131, 131, 131],
#           [131, 131, 131],
#           ...,
#           [155, 154, 150],
#           [153, 151, 150],
#           [153, 151, 151]],
#
#          [[131, 131, 131],
#           [131, 131, 131],
#           [131, 131, 131],
#           ...,
#           [156, 155, 151],
#           [154, 152, 151],
#           [154, 152, 152]],
#
#          ...,
#
#          [[155, 157, 157],
#           [155, 157, 157],
#           [132, 134, 134],
#           ...,
#           [144, 150, 155],
#           [140, 146, 151],
#           [136, 142, 147]],
#
#          [[127, 130, 130],
#           [161, 163, 163],
#           [141, 143, 143],
#           ...,
#           [142, 148, 153],
#           [150, 156, 161],
#           [152, 157, 162]],
#
#          [[114, 117, 117],
#           [150, 152, 152],
#           [152, 154, 154],
#           ...,
#           [142, 148, 153],
#           [145, 151, 156],
#           [146, 152, 157]]], dtype=uint8),
#   0],
# ...
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8),
#   0],
#  [array([[[155, 177, 183],
#           [159, 181, 188],
#           [162, 184, 190],
#           ...,
#           [217, 229, 233],
#           [218, 227, 230],
#           [219, 227, 229]],
#
#          [[158, 180, 186],
#           [156, 178, 185],
#           [154, 176, 182],
#           ...,
#           [216, 227, 231],
#           [217, 227, 230],
#           [218, 227, 229]],
#
#          [[155, 175, 182],
#           [154, 172, 179],
#           [147, 166, 173],
#           ...,
#           [216, 228, 232],
#           [216, 228, 230],
#           [218, 227, 229]],
#
#          ...,
#
#          [[145, 162, 165],
#           [ 93, 110, 113],
#           [ 89, 106, 109],
#           ...,
#           [ 67,  94,  99],
#           [109, 139, 142],
#           [104, 133, 139]],
#
#          [[150, 167, 170],
#           [ 91, 108, 111],
#           [ 75,  92,  95],
#           ...,
#           [ 69,  95,  99],
#           [110, 137, 141],
#           [104, 133, 139]],
#
#          [[151, 164, 168],
#           [ 98, 111, 115],
#           [ 70,  83,  86],
#           ...,
#           [ 75,  97, 101],
#           [111, 135, 140],
#           [106, 131, 138]]], dtype=uint8),
#   0],
#  [array([[[  6,  14,  13],
#           [  7,  15,  14],
#           [ 11,  17,  16],
#           ...,
#           [  1,   3,   3],
#           [  1,   3,   3],
#           [  1,   3,   3]],
#
#          [[  3,  15,  13],
#           [  0,  10,   8],
#           [  2,  10,   9],
#           ...,
#           [  0,   2,   2],
#           [  1,   2,   2],
#           [  1,   2,   2]],
#
#          [[ 10,  24,  22],
#           [  0,  12,  11],
#           [  1,  12,  10],
#           ...,
#           [  0,   1,   1],
#           [  0,   0,   0],
#           [  0,   0,   0]],
#
#          ...,
#
#          [[ 62,  74,  92],
#           [ 64,  76,  94],
#           [ 66,  78,  96],
#           ...,
#           [177, 180, 188],
#           [175, 178, 184],
#           [175, 175, 181]],
#
#          [[ 65,  76,  94],
#           [ 67,  79,  97],
#           [ 69,  80,  98],
#           ...,
#           [179, 182, 190],
#           [178, 180, 187],
#           [177, 177, 183]],
#
#          [[ 66,  78,  96],
#           [ 67,  79,  98],
#           [ 70,  82, 100],
#           ...,
#           [177, 179, 188],
#           [179, 182, 188],
#           [178, 179, 184]]], dtype=uint8),
#   0],
#  [array([[[ 96,  78,  79],
#           [ 91,  73,  74],
#           [ 91,  73,  73],
#           ...,
#           [ 88,  72,  66],
#           [ 84,  68,  62],
#           [ 77,  61,  55]],
#
#          [[103,  85,  86],
#           [ 90,  72,  73],
#           [ 92,  74,  74],
#           ...,
#           [ 78,  62,  56],
#           [ 96,  80,  74],
#           [ 89,  73,  67]],
#
#          [[102,  83,  85],
#           [ 88,  70,  72],
#           [ 93,  75,  75],
#           ...,
#           [ 94,  79,  73],
#           [ 97,  81,  75],
#           [ 91,  75,  69]],
#
#          ...,
#
#          [[ 35,  29,  30],
#           [ 39,  33,  34],
#           [ 37,  31,  32],
#           ...,
#           [  5,  17,  40],
#           [  5,  16,  38],
#           [  4,  15,  35]],
#
#          [[ 32,  26,  27],
#           [ 35,  29,  30],
#           [ 34,  28,  29],
#           ...,
#           [  8,  19,  40],
#           [  7,  17,  37],
#           [  8,  17,  36]],
#
#          [[ 32,  26,  27],
#           [ 32,  26,  27],
#           [ 29,  23,  24],
#           ...,
#           [  5,  14,  34],
#           [  5,  15,  34],
#           [  6,  16,  34]]], dtype=uint8),
#   0],
#  [array([[[128, 128, 128],
#           [125, 125, 125],
#           [123, 123, 123],
#           ...,
#           [ 89, 106, 118],
#           [ 90, 104, 115],
#           [ 87,  99, 109]],
#
#          [[122, 122, 122],
#           [124, 124, 124],
#           [120, 120, 120],
#           ...,
#           [ 88, 104, 117],
#           [ 93, 108, 119],
#           [ 95, 107, 117]],
#
#          [[122, 122, 122],
#           [122, 122, 122],
#           [116, 116, 116],
#           ...,
#           [ 88, 104, 117],
#           [ 85,  99, 110],
#           [ 89, 101, 111]],
#
#          ...,
#
#          [[117, 151, 161],
#           [130, 162, 173],
#           [133, 161, 173],
#           ...,
#           [123, 159, 172],
#           [121, 158, 176],
#           [124, 156, 178]],
#
#          [[ 78, 104, 116],
#           [ 79, 104, 115],
#           [ 79,  98, 111],
#           ...,
#           [109, 146, 154],
#           [103, 138, 154],
#           [110, 136, 161]],
#
#          [[106, 120, 126],
#           [104, 116, 122],
#           [107, 118, 125],
#           ...,
#           [ 67,  91, 108],
#           [111, 132, 149],
#           [105, 143, 156]]], dtype=uint8),
#   0],
#  [array([[[ 32,  30,  29],
#           [ 34,  32,  31],
#           [ 45,  43,  42],
#           ...,
#           [ 42,  42,  42],
#           [ 41,  41,  41],
#           [ 54,  54,  54]],
#
#          [[ 34,  32,  31],
#           [ 35,  33,  32],
#           [ 47,  45,  44],
#           ...,
#           [ 40,  40,  40],
#           [ 47,  47,  47],
#           [ 59,  59,  59]],
#
#          [[ 35,  33,  32],
#           [ 38,  36,  35],
#           [ 51,  49,  48],
#           ...,
#           [ 40,  40,  40],
#           [ 42,  42,  42],
#           [ 53,  53,  53]],
#
#          ...,
#
#          [[226, 219, 150],
#           [217, 210, 141],
#           [207, 201, 135],
#           ...,
#           [244, 240, 190],
#           [242, 238, 190],
#           [239, 235, 188]],
#
#          [[219, 209, 139],
#           [214, 205, 136],
#           [221, 211, 147],
#           ...,
#           [240, 235, 190],
#           [238, 232, 190],
#           [235, 229, 188]],
#
#          [[210, 209, 143],
#           [228, 225, 164],
#           [237, 233, 179],
#           ...,
#           [243, 234, 184],
#           [239, 230, 180],
#           [239, 230, 180]]], dtype=uint8),
#   0],
#  [array([[[ 41,  54,  72],
#           [ 42,  55,  71],
#           [ 42,  55,  70],
#           ...,
#           [ 94,  50,  33],
#           [ 97,  52,  35],
#           [ 98,  52,  35]],
#
#          [[ 43,  56,  72],
#           [ 43,  56,  72],
#           [ 43,  55,  70],
#           ...,
#           [ 94,  50,  33],
#           [ 96,  51,  35],
#           [ 98,  51,  35]],
#
#          [[ 43,  56,  72],
#           [ 43,  56,  72],
#           [ 44,  55,  69],
#           ...,
#           [ 93,  49,  32],
#           [ 95,  51,  34],
#           [ 97,  51,  34]],
#
#          ...,
#
#          [[135, 135, 135],
#           [143, 143, 143],
#           [128, 128, 128],
#           ...,
#           [171, 169, 169],
#           [148, 146, 146],
#           [ 98,  96,  96]],
#
#          [[140, 140, 140],
#           [139, 139, 139],
#           [134, 134, 134],
#           ...,
#           [159, 157, 157],
#           [153, 151, 151],
#           [132, 130, 130]],
#
#          [[167, 167, 167],
#           [156, 156, 156],
#           [155, 155, 155],
#           ...,
#           [151, 149, 149],
#           [154, 152, 152],
#           [154, 152, 152]]], dtype=uint8),
#   0],
#  [array([[[ 31,  33,  41],
#           [ 32,  34,  42],
#           [ 32,  34,  42],
#           ...,
#           [ 29,  32,  36],
#           [ 25,  29,  30],
#           [ 21,  23,  31]],
#
#          [[ 31,  33,  41],
#           [ 32,  34,  42],
#           [ 30,  31,  40],
#           ...,
#           [ 27,  30,  34],
#           [ 24,  27,  30],
#           [ 22,  24,  32]],
#
#          [[ 36,  38,  46],
#           [ 30,  31,  39],
#           [ 30,  32,  40],
#           ...,
#           [ 26,  29,  34],
#           [ 25,  28,  32],
#           [ 20,  22,  30]],
#
#          ...,
#
#          [[ 46,  50,  56],
#           [ 76,  81,  92],
#           [ 96, 105, 108],
#           ...,
#           [ 42,  60,  63],
#           [ 37,  41,  44],
#           [ 78, 105, 116]],
#
#          [[ 76,  79,  93],
#           [ 91,  99, 100],
#           [104, 109, 110],
#           ...,
#           [ 42,  51,  54],
#           [106, 118, 122],
#           [ 63,  90, 100]],
#
#          [[ 85,  90, 110],
#           [ 89,  96,  90],
#           [ 78,  81,  81],
#           ...,
#           [120, 119, 127],
#           [ 51,  69,  78],
#           [ 67,  86,  96]]], dtype=uint8),
#   0],
#  [array([[[ 78,  49,  34],
#           [119,  93,  77],
#           [136, 115,  98],
#           ...,
#           [255, 249, 250],
#           [253, 252, 253],
#           [235, 239, 238]],
#
#          [[ 77,  51,  35],
#           [120,  95,  79],
#           [138, 117, 100],
#           ...,
#           [240, 233, 234],
#           [255, 254, 255],
#           [251, 255, 255]],
#
#          [[ 78,  52,  38],
#           [120,  96,  82],
#           [138, 118, 103],
#           ...,
#           [255, 254, 255],
#           [235, 235, 235],
#           [239, 243, 242]],
#
#          ...,
#
#          [[ 39,  48,  59],
#           [ 41,  52,  64],
#           [ 43,  54,  68],
#           ...,
#           [ 83,  81,  80],
#           [ 75,  77,  75],
#           [ 72,  77,  76]],
#
#          [[ 35,  44,  55],
#           [ 37,  47,  60],
#           [ 37,  48,  62],
#           ...,
#           [ 83,  81,  80],
#           [ 74,  76,  74],
#           [ 73,  78,  77]],
#
#          [[ 32,  42,  52],
#           [ 33,  44,  56],
#           [ 33,  45,  58],
#           ...,
#           [ 80,  78,  77],
#           [ 74,  76,  74],
#           [ 75,  79,  78]]], dtype=uint8),
#   0],
#  [array([[[199, 213, 235],
#           [200, 208, 233],
#           [204, 208, 236],
#           ...,
#           [149, 154, 153],
#           [ 28,  30,  30],
#           [ 29,  29,  29]],
#
#          [[186, 200, 222],
#           [192, 200, 225],
#           [198, 202, 230],
#           ...,
#           [159, 164, 163],
#           [ 36,  38,  38],
#           [ 27,  27,  27]],
#
#          [[192, 205, 227],
#           [197, 203, 228],
#           [199, 202, 230],
#           ...,
#           [174, 179, 178],
#           [241, 243, 243],
#           [242, 242, 242]],
#
#          ...,
#
#          [[217, 207, 220],
#           [218, 208, 221],
#           [218, 208, 221],
#           ...,
#           [ 68,  80,  83],
#           [245, 244, 241],
#           [246, 247, 243]],
#
#          [[217, 206, 222],
#           [218, 207, 223],
#           [219, 208, 224],
#           ...,
#           [ 69,  79,  83],
#           [246, 244, 241],
#           [246, 247, 243]],
#
#          [[217, 205, 223],
#           [218, 206, 224],
#           [220, 208, 226],
#           ...,
#           [ 70,  79,  83],
#           [247, 243, 241],
#           [246, 247, 243]]], dtype=uint8),
#   0],
#  [array([[[25, 15,  5],
#           [25, 15,  5],
#           [26, 15,  6],
#           ...,
#           [20, 10,  3],
#           [20, 10,  3],
#           [22,  9,  7]],
#
#          [[25, 15,  5],
#           [25, 15,  5],
#           [24, 15,  5],
#           ...,
#           [20, 10,  3],
#           [22, 12,  5],
#           [21,  8,  6]],
#
#          [[24, 15,  5],
#           [24, 15,  5],
#           [23, 14,  4],
#           ...,
#           [22, 11,  7],
#           [22, 11,  7],
#           [23, 12,  9]],
#
#          ...,
#
#          [[22, 29, 22],
#           [24, 28, 22],
#           [28, 30, 23],
#           ...,
#           [46, 44, 50],
#           [48, 45, 50],
#           [48, 42, 46]],
#
#          [[21, 28, 22],
#           [27, 31, 25],
#           [24, 25, 20],
#           ...,
#           [44, 42, 48],
#           [46, 44, 48],
#           [42, 44, 48]],
#
#          [[18, 24, 20],
#           [25, 29, 24],
#           [47, 48, 44],
#           ...,
#           [41, 39, 45],
#           [44, 41, 46],
#           [37, 43, 48]]], dtype=uint8),
#   0],
#  [array([[[ 35,  66, 119],
#           [ 35,  66, 119],
#           [ 34,  65, 118],
#           ...,
#           [ 28,  63, 119],
#           [ 26,  61, 117],
#           [ 24,  59, 115]],
#
#          [[ 39,  70, 123],
#           [ 38,  69, 122],
#           [ 37,  68, 121],
#           ...,
#           [ 32,  67, 123],
#           [ 31,  66, 122],
#           [ 30,  65, 121]],
#
#          [[ 41,  75, 128],
#           [ 41,  74, 127],
#           [ 40,  73, 126],
#           ...,
#           [ 36,  71, 127],
#           [ 36,  71, 127],
#           [ 35,  70, 126]],
#
#          ...,
#
#          [[152, 147, 167],
#           [171, 171, 190],
#           [206, 216, 231],
#           ...,
#           [123, 139, 156],
#           [147, 167, 186],
#           [148, 171, 192]],
#
#          [[175, 177, 195],
#           [200, 209, 225],
#           [215, 235, 247],
#           ...,
#           [ 74,  90, 106],
#           [114, 133, 151],
#           [138, 159, 180]],
#
#          [[207, 217, 235],
#           [215, 234, 248],
#           [208, 238, 249],
#           ...,
#           [ 48,  63,  80],
#           [ 94, 112, 130],
#           [122, 143, 164]]], dtype=uint8),
#   0],
#  [array([[[ 85,  78,  63],
#           [ 78,  71,  57],
#           [ 77,  70,  55],
#           ...,
#           [155, 140, 121],
#           [154, 139, 120],
#           [126, 116,  97]],
#
#          [[ 88,  81,  67],
#           [ 90,  83,  69],
#           [ 89,  82,  68],
#           ...,
#           [158, 143, 124],
#           [157, 142, 123],
#           [138, 124, 106]],
#
#          [[ 88,  80,  67],
#           [ 87,  80,  67],
#           [ 90,  81,  68],
#           ...,
#           [161, 146, 127],
#           [160, 145, 126],
#           [144, 126, 109]],
#
#          ...,
#
#          [[120, 105,  91],
#           [125, 108,  92],
#           [151, 131, 114],
#           ...,
#           [ 98,  98,  94],
#           [106, 105,  95],
#           [ 89,  96,  88]],
#
#          [[117, 104,  88],
#           [124, 108,  92],
#           [148, 127, 112],
#           ...,
#           [ 88,  86,  85],
#           [ 98,  99,  91],
#           [ 88,  89,  85]],
#
#          [[115, 103,  87],
#           [121, 105,  89],
#           [141, 120, 105],
#           ...,
#           [ 76,  74,  73],
#           [ 86,  86,  79],
#           [ 80,  81,  77]]], dtype=uint8),
#   0],
#  [array([[[252, 249, 241],
#           [255, 253, 246],
#           [254, 254, 249],
#           ...,
#           [107, 100, 103],
#           [103,  96,  99],
#           [ 91,  96,  91]],
#
#          [[255, 252, 244],
#           [254, 252, 246],
#           [255, 254, 250],
#           ...,
#           [108, 101, 104],
#           [103,  96,  99],
#           [ 95,  94,  94]],
#
#          [[254, 251, 243],
#           [255, 253, 246],
#           [255, 254, 250],
#           ...,
#           [106,  99, 103],
#           [100,  93,  96],
#           [ 99,  92,  95]],
#
#          ...,
#
#          [[ 54,  87, 122],
#           [ 60,  96, 134],
#           [ 51,  90, 128],
#           ...,
#           [209, 208, 210],
#           [177, 176, 178],
#           [172, 163, 176]],
#
#          [[ 76, 114, 148],
#           [ 70, 108, 146],
#           [ 52,  93, 131],
#           ...,
#           [195, 194, 198],
#           [172, 171, 175],
#           [126, 118, 130]],
#
#          [[ 85, 130, 163],
#           [ 77, 120, 157],
#           [ 56,  99, 137],
#           ...,
#           [201, 200, 204],
#           [168, 166, 171],
#           [161, 159, 166]]], dtype=uint8),
#   0],
#  [array([[[  6,   6,   6],
#           [  6,   6,   6],
#           [  5,   5,   5],
#           ...,
#           [112,  53,  13],
#           [116,  55,  16],
#           [111,  51,  22]],
#
#          [[  6,   6,   6],
#           [  6,   6,   6],
#           [  8,   8,   8],
#           ...,
#           [116,  57,  10],
#           [118,  58,  12],
#           [111,  50,  17]],
#
#          [[  6,   6,   6],
#           [  6,   6,   6],
#           [  7,   7,   7],
#           ...,
#           [122,  62,   7],
#           [117,  58,   5],
#           [114,  51,  15]],
#
#          ...,
#
#          [[ 99, 177, 124],
#           [102, 180, 127],
#           [101, 178, 126],
#           ...,
#           [ 98, 187, 126],
#           [ 89, 178, 114],
#           [ 85, 175, 113]],
#
#          [[ 94, 181, 115],
#           [ 96, 182, 118],
#           [ 98, 183, 121],
#           ...,
#           [ 88, 184, 117],
#           [ 77, 171, 114],
#           [ 79, 170, 101]],
#
#          [[ 94, 182, 116],
#           [ 96, 183, 119],
#           [ 99, 185, 123],
#           ...,
#           [ 85, 180, 113],
#           [ 83, 177, 120],
#           [ 80, 171, 102]]], dtype=uint8),
#   0],
#  ...]

# %%
random.shuffle(data)

# %%
X = []
y =[]
for i in data:
    X.append(i[0])
    y.append(i[1])

# %%
y = np.array(y)

# %%
X = np.array(X)

# %%
X.shape
# Out:
# (2343, 150, 150, 3)

# %%
y.shape
# Out:
# (2343,)

# %%
X = X/255

# %%
# Create a CNNN 
from keras import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense , Flatten , Activation , Dropout

# %%
model = Sequential()
model.add(Conv2D(32, (3,3) , input_shape=(150,150,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# Out:
# C:\Users\himan\anaconda3\envs\dl\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(Flatten())  #this converts our 3D feature maps to 1D feture vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='rmsprop' , metrics=['accuracy'])

# %%
model.fit(X , y , epochs=5, validation_split=0.1)
# Out:
# Epoch 1/5
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 210ms/step - accuracy: 0.5342 - loss: 0.7800 - val_accuracy: 0.5404 - val_loss: 0.6925
# Epoch 2/5
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.5489 - loss: 0.6962 - val_accuracy: 0.5660 - val_loss: 0.6829
# Epoch 3/5
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 13s 199ms/step - accuracy: 0.5797 - loss: 0.6880 - val_accuracy: 0.4723 - val_loss: 0.7095
# Epoch 4/5
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.6091 - loss: 0.6704 - val_accuracy: 0.6426 - val_loss: 0.6364
# Epoch 5/5
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.6537 - loss: 0.6251 - val_accuracy: 0.6894 - val_loss: 0.6077

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 model.fit_generator(
#       2     train_generator,
#       3     steps_per_epochs=2000//batch_size,
#       4     epochs=25,
#       5     validation_data=validation_generator,
#       6     validation_steps=800//batch_size
#       7 )
#
# AttributeError: 'Sequential' object has no attribute 'fit_generator'
